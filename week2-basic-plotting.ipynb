# %%
import pandas as pd

# Read in file
df = pd.read_csv('data/wetlands_seasonal_bird_diversity.csv')

# Check the first 5 rows
df.head()

# Default plot(): one line plot per column with numeric data
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Birds species registered during winter at CSM yearly
df.plot(x='year', y='CSM_winter')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.plot(x='year', 
        y='CSM_winter',
        title='Bird species registered during winter at Carpinteria Salt Marsh',
        xlabel='Year',
        ylabel='Number of bird species',
        color='green',
        legend=False
        )
# Out:
# <AxesSubplot:title={'center':'Bird species registered during winter at Carpinteria Salt Marsh'}, xlabel='Year', ylabel='Number of bird species'>

# %% [markdown]
# # Check in:
# ### Plot a graph of the bird surveys at Mugu Lagoon with respect to the years. Include some basic customization.

# %%
df.plot(x='year',
        y=['MUL_winter','MUL_spring','MUL_fall'],
        title='Birds surveyed at Point Mugu Lagoon',
        xlabel='Year',
        ylabel='Number of birds surveyed',
        legend=True
        )
# Out:
# <AxesSubplot:title={'center':'Birds surveyed at Point Mugu Lagoon'}, xlabel='Year', ylabel='Number of birds surveyed'>

# %% [markdown]
# ### Updating the index

# %%
# Update index to be the year column
df = df.set_index('year')
df.head()
# Out:
#       CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# year
# 2010        39.0        40.0      50.0        45.0         NaN      61.0
# 2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2012        51.0        43.0      49.0        57.0        58.0      53.0
# 2013        42.0        46.0      38.0        60.0        58.0      62.0
# 2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#       SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# year
# 2010         NaN        75.0      85.0         NaN         NaN      81.0
# 2011        78.0        74.0       NaN        67.0        70.0       NaN
# 2012        71.0        72.0      73.0        70.0        63.0      69.0
# 2013        69.0        70.0      70.0        69.0        74.0      64.0
# 2014        61.0        78.0      71.0        60.0        81.0      62.0

# %%
df = df.reset_index()
df.head()
# Out:
#    year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0  2010        39.0        40.0      50.0        45.0         NaN      61.0
# 1  2011        48.0        44.0       NaN        58.0        52.0       NaN
# 2  2012        51.0        43.0      49.0        57.0        58.0      53.0
# 3  2013        42.0        46.0      38.0        60.0        58.0      62.0
# 4  2014        38.0        43.0      45.0        49.0        52.0      57.0
#
#    SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0         NaN        75.0      85.0         NaN         NaN      81.0
# 1        78.0        74.0       NaN        67.0        70.0       NaN
# 2        71.0        72.0      73.0        70.0        63.0      69.0
# 3        69.0        70.0      70.0        69.0        74.0      64.0
# 4        61.0        78.0      71.0        60.0        81.0      62.0

# %% [markdown]
# # Check-In 2
#
#
# ### Without running the code, give a step-by-step breakdown of what this code is doing:
# df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()
#
# 1. sets the index to year
# 2. subsets to all the columns including and between SDW_winter to TJE_fall
# 3. generates a plot
#
# ### Is this code modifying the data frame df? Why or why not?
# No it is just showing a view on the fly
#
# ### Run the code and examine the graph. Do we have all the necessary information to make sure it makes sense to directly compare the surveys at these different sites?
# The coloring makes it hard to compare the charts

# %%
df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## Class Activity

# %%
# Read in data
URL = 'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv'
penguins = pd.read_csv(URL)

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
# Check column data types and NA values
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
# Count unique values in categorical columns and year
penguins[['species', 'island', 'sex', 'year']].nunique()
# Out:
# species    3
# island     3
# sex        2
# year       3
# dtype: int64

# %%
# Get unique values in species column
# Tells you which are the unique values
penguins['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
# Number of values per unique value in species column
# Gives you count per unique species
penguins['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64
